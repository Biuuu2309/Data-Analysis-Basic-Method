# %% [markdown]
# DATA CLEANING

# %%
import pandas as pd
import numpy as np
import csv
import random

YT_Table = pd.read_csv('E:\Data Analysis Basic Method\Project\Data-Analysis-Basic-Method\Dataset5\Youtube_Test.csv')
YT_Table
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\minhv\AppData\Local\Temp\ipykernel_2408\2443522030.py:6: SyntaxWarning: invalid escape sequence '\D'
#   YT_Table = pd.read_csv('E:\Data Analysis Basic Method\Project\Data-Analysis-Basic-Method\Dataset5\Youtube_Test.csv')
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags    views   likes  \
# 0                                         SHANtell martin   748374   57527
# 1       last week tonight trump presidency|"last week ...  2418783   97185
# 2       racist superman|"rudy""|""mancuso""|""king""|"...  3191434  146033
# 3       rhett and link|"gmm""|""good mythical morning"...   343168   10172
# 4       ryan|"higa""|""higatv""|""nigahiga""|""i dare ...  2095731  132235
# ...                                                   ...      ...     ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685    1701
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339     460
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347   25900
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225    2115
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392     300
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0           2966          15954              False             False
# 1           6146          12703              False             False
# 2           5339           8181              False             False
# 3            666           2146              False             False
# 4           1989          17518              False             False
# ...          ...            ...                ...               ...
# 161465        99           1312              False             False
# 161466        66             51              False             False
# 161467       224           3881              False             False
# 161468       182           1672              False             False
# 161469        62            251              False             False
#
#         video_error_or_removed
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 161465                   False
# 161466                   False
# 161467                   False
# 161468                   False
# 161469                   False
#
# [161470 rows x 18 columns]

# %% [markdown]
# KIEM TRA DU LIEU NULL

# %%
TBN = YT_Table[(YT_Table['video_id'].isnull()) | (YT_Table['trending_date'].isnull()) | (YT_Table['title'].isnull()) | (YT_Table['channel_title'].isnull()) | (YT_Table['category_id'].isnull()) | (YT_Table['publish_date'].isnull()) | (YT_Table['time_frame'].isnull()) | (YT_Table['published_day_of_week'].isnull()) | (YT_Table['publish_country'].isnull()) | (YT_Table['tags'].isnull()) | (YT_Table['views'].isnull()) | (YT_Table['likes'].isnull()) | (YT_Table['dislikes'].isnull()) | (YT_Table['comment_count'].isnull()) | (YT_Table['comments_disabled'].isnull()) | (YT_Table['ratings_disabled'].isnull()) | (YT_Table['video_error_or_removed'].isnull())]
TBN
# Out:
# Empty DataFrame
# Columns: [index, video_id, trending_date, title, channel_title, category_id, publish_date, time_frame, published_day_of_week, publish_country, tags, views, likes, dislikes, comment_count, comments_disabled, ratings_disabled, video_error_or_removed]
# Index: []

# %% [markdown]
# CHU DONG XOA DU LIEU TREN CAC FIELDS

# %% [markdown]
# 1. TAGS

# %%
YT_Table.loc[[i for i in range(0,5)], 'tags'] = np.nan
YT_Table
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags    views   likes  \
# 0                                                     NaN   748374   57527
# 1                                                     NaN  2418783   97185
# 2                                                     NaN  3191434  146033
# 3                                                     NaN   343168   10172
# 4                                                     NaN  2095731  132235
# ...                                                   ...      ...     ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685    1701
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339     460
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347   25900
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225    2115
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392     300
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0           2966          15954              False             False
# 1           6146          12703              False             False
# 2           5339           8181              False             False
# 3            666           2146              False             False
# 4           1989          17518              False             False
# ...          ...            ...                ...               ...
# 161465        99           1312              False             False
# 161466        66             51              False             False
# 161467       224           3881              False             False
# 161468       182           1672              False             False
# 161469        62            251              False             False
#
#         video_error_or_removed
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 161465                   False
# 161466                   False
# 161467                   False
# 161468                   False
# 161469                   False
#
# [161470 rows x 18 columns]

# %% [markdown]
# 2. VIEWS

# %%
YT_Table.loc[[i for i in range(5,9)], 'views'] = np.nan
YT_Table
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views   likes  \
# 0                                                     NaN   748374.0   57527
# 1                                                     NaN  2418783.0   97185
# 2                                                     NaN  3191434.0  146033
# 3                                                     NaN   343168.0   10172
# 4                                                     NaN  2095731.0  132235
# ...                                                   ...        ...     ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0    1701
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0     460
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0   25900
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0    2115
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0     300
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0           2966          15954              False             False
# 1           6146          12703              False             False
# 2           5339           8181              False             False
# 3            666           2146              False             False
# 4           1989          17518              False             False
# ...          ...            ...                ...               ...
# 161465        99           1312              False             False
# 161466        66             51              False             False
# 161467       224           3881              False             False
# 161468       182           1672              False             False
# 161469        62            251              False             False
#
#         video_error_or_removed
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 161465                   False
# 161466                   False
# 161467                   False
# 161468                   False
# 161469                   False
#
# [161470 rows x 18 columns]

# %% [markdown]
# 3. LIKES

# %%
YT_Table.loc[[i for i in range(9, 15)], 'likes'] = np.nan
YT_Table
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count  comments_disabled  \
# 0        57527.0      2966          15954              False
# 1        97185.0      6146          12703              False
# 2       146033.0      5339           8181              False
# 3        10172.0       666           2146              False
# 4       132235.0      1989          17518              False
# ...          ...       ...            ...                ...
# 161465    1701.0        99           1312              False
# 161466     460.0        66             51              False
# 161467   25900.0       224           3881              False
# 161468    2115.0       182           1672              False
# 161469     300.0        62            251              False
#
#         ratings_disabled  video_error_or_removed
# 0                  False                   False
# 1                  False                   False
# 2                  False                   False
# 3                  False                   False
# 4                  False                   False
# ...                  ...                     ...
# 161465             False                   False
# 161466             False                   False
# 161467             False                   False
# 161468             False                   False
# 161469             False                   False
#
# [161470 rows x 18 columns]

# %% [markdown]
# 4. DISLIKES

# %%
YT_Table.loc[[i for i in range(15, 20)], 'dislikes'] = np.nan
YT_Table
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count  comments_disabled  \
# 0        57527.0    2966.0          15954              False
# 1        97185.0    6146.0          12703              False
# 2       146033.0    5339.0           8181              False
# 3        10172.0     666.0           2146              False
# 4       132235.0    1989.0          17518              False
# ...          ...       ...            ...                ...
# 161465    1701.0      99.0           1312              False
# 161466     460.0      66.0             51              False
# 161467   25900.0     224.0           3881              False
# 161468    2115.0     182.0           1672              False
# 161469     300.0      62.0            251              False
#
#         ratings_disabled  video_error_or_removed
# 0                  False                   False
# 1                  False                   False
# 2                  False                   False
# 3                  False                   False
# 4                  False                   False
# ...                  ...                     ...
# 161465             False                   False
# 161466             False                   False
# 161467             False                   False
# 161468             False                   False
# 161469             False                   False
#
# [161470 rows x 18 columns]

# %% [markdown]
# 5. COMMENT COUNTS

# %%
YT_Table.loc[[i for i in range(20, 25)], 'comment_count'] = np.nan

# %% [markdown]
# 6. COMMENTS DISABLED

# %%
YT_Table.loc[[i for i in range(25, 30)], 'comments_disabled'] = np.nan
YT_Table
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_4240\2163865929.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   YT_Table.loc[[i for i in range(25, 30)], 'comments_disabled'] = np.nan
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count comments_disabled  ratings_disabled  \
# 0        57527.0    2966.0        15954.0             False             False
# 1        97185.0    6146.0        12703.0             False             False
# 2       146033.0    5339.0         8181.0             False             False
# 3        10172.0     666.0         2146.0             False             False
# 4       132235.0    1989.0        17518.0             False             False
# ...          ...       ...            ...               ...               ...
# 161465    1701.0      99.0         1312.0             False             False
# 161466     460.0      66.0           51.0             False             False
# 161467   25900.0     224.0         3881.0             False             False
# 161468    2115.0     182.0         1672.0             False             False
# 161469     300.0      62.0          251.0             False             False
#
#         video_error_or_removed
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 161465                   False
# 161466                   False
# 161467                   False
# 161468                   False
# 161469                   False
#
# [161470 rows x 18 columns]

# %% [markdown]
# 7. RATINGS DISABLED

# %%
YT_Table.loc[[i for i in range(30, 35)], 'ratings_disabled'] = np.nan
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_4240\375963192.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   YT_Table.loc[[i for i in range(30, 35)], 'ratings_disabled'] = np.nan

# %% [markdown]
# 8. VIDEO ERROR OR REMOVED

# %%
YT_Table.loc[[i for i in range(35, 40)], 'video_error_or_removed'] = np.nan
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_4240\2492082756.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'nan' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   YT_Table.loc[[i for i in range(35, 40)], 'video_error_or_removed'] = np.nan

# %% [markdown]
# DIEN GIA TRI CON THIEU

# %% [markdown]
# VIEWS

# %%
DF = pd.DataFrame(YT_Table)
MMM = [int(DF['views'].mean()), int(DF['views'].mode()[0]), int(DF['views'].median())]
DF['views'].fillna(min(MMM), inplace=True)
DF
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_2408\4111462111.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   DF['views'].fillna(min(MMM), inplace=True)
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags    views   likes  \
# 0                                         SHANtell martin   748374   57527
# 1       last week tonight trump presidency|"last week ...  2418783   97185
# 2       racist superman|"rudy""|""mancuso""|""king""|"...  3191434  146033
# 3       rhett and link|"gmm""|""good mythical morning"...   343168   10172
# 4       ryan|"higa""|""higatv""|""nigahiga""|""i dare ...  2095731  132235
# ...                                                   ...      ...     ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685    1701
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339     460
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347   25900
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225    2115
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392     300
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0           2966          15954              False             False
# 1           6146          12703              False             False
# 2           5339           8181              False             False
# 3            666           2146              False             False
# 4           1989          17518              False             False
# ...          ...            ...                ...               ...
# 161465        99           1312              False             False
# 161466        66             51              False             False
# 161467       224           3881              False             False
# 161468       182           1672              False             False
# 161469        62            251              False             False
#
#         video_error_or_removed
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 161465                   False
# 161466                   False
# 161467                   False
# 161468                   False
# 161469                   False
#
# [161470 rows x 18 columns]

# %% [markdown]
# LIKES

# %%
MMM = [int(DF['likes'].mean()), int(DF['likes'].mode()[0]), int(DF['likes'].median())]
DF['likes'].fillna(min(MMM), inplace=True)
DF
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_4240\2050711628.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   DF['likes'].fillna(min(MMM), inplace=True)
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count comments_disabled ratings_disabled  \
# 0        57527.0    2966.0        15954.0             False            False
# 1        97185.0    6146.0        12703.0             False            False
# 2       146033.0    5339.0         8181.0             False            False
# 3        10172.0     666.0         2146.0             False            False
# 4       132235.0    1989.0        17518.0             False            False
# ...          ...       ...            ...               ...              ...
# 161465    1701.0      99.0         1312.0             False            False
# 161466     460.0      66.0           51.0             False            False
# 161467   25900.0     224.0         3881.0             False            False
# 161468    2115.0     182.0         1672.0             False            False
# 161469     300.0      62.0          251.0             False            False
#
#        video_error_or_removed
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 161465                  False
# 161466                  False
# 161467                  False
# 161468                  False
# 161469                  False
#
# [161470 rows x 18 columns]

# %% [markdown]
# DISLIKES

# %%
MMM = [int(DF['dislikes'].mean()), int(DF['dislikes'].mode()[0]), int(DF['dislikes'].median())]
DF['dislikes'].fillna(min(MMM), inplace=True)
DF
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_4240\2439982794.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   DF['dislikes'].fillna(min(MMM), inplace=True)
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count comments_disabled ratings_disabled  \
# 0        57527.0    2966.0        15954.0             False            False
# 1        97185.0    6146.0        12703.0             False            False
# 2       146033.0    5339.0         8181.0             False            False
# 3        10172.0     666.0         2146.0             False            False
# 4       132235.0    1989.0        17518.0             False            False
# ...          ...       ...            ...               ...              ...
# 161465    1701.0      99.0         1312.0             False            False
# 161466     460.0      66.0           51.0             False            False
# 161467   25900.0     224.0         3881.0             False            False
# 161468    2115.0     182.0         1672.0             False            False
# 161469     300.0      62.0          251.0             False            False
#
#        video_error_or_removed
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 161465                  False
# 161466                  False
# 161467                  False
# 161468                  False
# 161469                  False
#
# [161470 rows x 18 columns]

# %% [markdown]
# COMMENT COUNT

# %%
MMM = [int(DF['comment_count'].mean()), int(DF['comment_count'].mode()[0]), int(DF['comment_count'].median())]
DF['comment_count'].fillna(min(MMM), inplace=True)
DF
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_4240\2539717307.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   DF['comment_count'].fillna(min(MMM), inplace=True)
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count comments_disabled ratings_disabled  \
# 0        57527.0    2966.0        15954.0             False            False
# 1        97185.0    6146.0        12703.0             False            False
# 2       146033.0    5339.0         8181.0             False            False
# 3        10172.0     666.0         2146.0             False            False
# 4       132235.0    1989.0        17518.0             False            False
# ...          ...       ...            ...               ...              ...
# 161465    1701.0      99.0         1312.0             False            False
# 161466     460.0      66.0           51.0             False            False
# 161467   25900.0     224.0         3881.0             False            False
# 161468    2115.0     182.0         1672.0             False            False
# 161469     300.0      62.0          251.0             False            False
#
#        video_error_or_removed
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 161465                  False
# 161466                  False
# 161467                  False
# 161468                  False
# 161469                  False
#
# [161470 rows x 18 columns]

# %% [markdown]
# COMMENTS DISABLED

# %% [markdown]
# Random by percent

# %%
true_ratio = len(DF[DF['comments_disabled'] == True]) / len(DF)

random_fill = np.random.choice([True, False], size=len(DF), p=[true_ratio, 1 - true_ratio])

DF['comments_disabled'] = DF['comments_disabled'].fillna(pd.Series(random_fill))

# %% [markdown]
# RATINGS DISABLED

# %%
true_ratio = len(DF[DF['ratings_disabled'] == True]) / len(DF)

random_fill = np.random.choice([True, False], size=len(DF), p=[true_ratio, 1 - true_ratio])

DF['ratings_disabled'] = DF['ratings_disabled'].fillna(pd.Series(random_fill))
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_4240\2260508977.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   DF['ratings_disabled'] = DF['ratings_disabled'].fillna(pd.Series(random_fill))

# %% [markdown]
# VIDEO ERROR OR REMOVED

# %%
true_ratio = len(DF[DF['video_error_or_removed'] == True]) / len(DF)

random_fill = np.random.choice([True, False], size=len(DF), p=[true_ratio, 1 - true_ratio])

DF['video_error_or_removed'] = DF['video_error_or_removed'].fillna(pd.Series(random_fill))

# %% [markdown]
# TAGS

# %%
DFF = DF[DF['tags'].isna()]
DFF['tags'].fillna(0, inplace=True)

tags = ''
lst = []
for i in range(len(DFF)):  
    lst = DFF.loc[i, 'title'].split() 
    for j in range(len(lst)):  
        if j == 0:
            tags += str(lst[j]) + '|"'  
        elif j == len(lst) - 1:
            tags += str(lst[j]) + '"""'  
        else:
            tags += str(lst[j]) + '""|""'  
    tags = tags.strip()
    for char in ":()?!":
        tags = tags.replace(char, "")
    DFF.loc[i, 'tags'] = tags 
    tags = ''
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_4240\2728719399.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   DFF['tags'].fillna(0, inplace=True)
# C:\Users\minhv\AppData\Local\Temp\ipykernel_4240\2728719399.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   DFF['tags'].fillna(0, inplace=True)
# C:\Users\minhv\AppData\Local\Temp\ipykernel_4240\2728719399.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DFF['tags'].fillna(0, inplace=True)
# C:\Users\minhv\AppData\Local\Temp\ipykernel_4240\2728719399.py:18: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'WE|"WANT""|""TO""|""TALK""|""ABOUT""|""OUR""|""MARRIAGE"""' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   DFF.loc[i, 'tags'] = tags

# %% [markdown]
# TAGS [none]

# %%
DF_2 = DF[DF['tags'] == '[none]']

DF_2.reset_index(drop=True, inplace=True)

for i in range(len(DF_2)):  
    lst = DF_2.loc[i, 'title'].split()  
    tags_list = []
    for j in range(len(lst)):  
        if j == 0:
            tags_list.append(str(lst[j]) + '|"')  
        elif j == len(lst) - 1:
            tags_list.append(str(lst[j]) + '"""')  
        else:
            tags_list.append(str(lst[j]) + '""|""')  
    
    tags = ''.join(tags_list).strip()
    for char in ":()?!":
        tags = tags.replace(char, "")
    
    DF_2.loc[i, 'tags'] = tags
DF.loc[DF['tags'] == '[none]', ['title', 'tags']] = DF_2[['title', 'tags']].values

# %% [markdown]
# LAM MIN DU LIEU

# %% [markdown]
# VIEWS - MEAN - 5 NHOM

# %%
DFS = DF.sort_values(by='views', ascending=True)
DF1 = DFS[:int(len(DFS)/5)]
DF2 = DFS[int(len(DFS)/5):int(len(DFS)/5)*2]
DF3 = DFS[int(len(DFS)/5)*2:int(len(DFS)/5)*3]
DF4 = DFS[int(len(DFS)/5)*3:int(len(DFS)/5)*4]
DF5 = DFS[int(len(DFS)/5)*4:]

DFS.loc[[i for i in range(0,int(len(DFS)/5))], 'views'] = int(DF1['views'].mean())
DFS.loc[[i for i in range(int(len(DFS)/5),int(len(DFS)/5)*2)], 'views'] = int(DF2['views'].mean())
DFS.loc[[i for i in range(int(len(DFS)/5)*2,int(len(DFS)/5)*3)], 'views'] = int(DF3['views'].mean())
DFS.loc[[i for i in range(int(len(DFS)/5)*3,int(len(DFS)/5)*4)], 'views'] = int(DF4['views'].mean())
DFS.loc[[i for i in range(int(len(DFS)/5)*4,len(DFS))], 'views'] = int(DF5['views'].mean())
DFS
# Out:
#          index     video_id trending_date  \
# 98184    98184       #NAME?      18.15.02
# 99531    99531  SBTD6BOTvWw      18.22.02
# 103725  103725  84auGGyG7rw      18.15.03
# 100880  100880  SoYtf4F7hsw      18.01.03
# 100974  100974  dGjVf5DWvEo      18.01.03
# ...        ...          ...           ...
# 68564    68564  _I_D_8Z4sJE      18.03.04
# 68760    68760  _I_D_8Z4sJE      18.04.04
# 68957    68957  _I_D_8Z4sJE      18.05.04
# 69161    69161  _I_D_8Z4sJE      18.06.04
# 69361    69361  _I_D_8Z4sJE      18.07.04
#
#                                                     title      channel_title  \
# 98184   Laurent Baffie - Best of des vannes #105 [inÃ©...        okaminaTv 4
# 99531   Zemmour et Naulleau - 21 FÃ©vrier 2018 - Emiss...    Politika France
# 103725  France: Famous climber Alain Rober scales skys...      No Comment TV
# 100880  L'histoire des enfants Tinning | La mÃ¨re aux ...  NavylittleMonster
# 100974               FeÌvrier 2018, Performance 8 10 Ans         Melimelo78
# ...                                                   ...                ...
# 68564   Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...         NickyJamTV
# 68760   Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...         NickyJamTV
# 68957   Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...         NickyJamTV
# 69161   Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...         NickyJamTV
# 69361   Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...         NickyJamTV
#
#         category_id publish_date      time_frame published_day_of_week  \
# 98184            24   15/02/2018  12:00 to 12:59              Thursday
# 99531            25   22/02/2018    4:00 to 4:59              Thursday
# 103725           25   14/03/2018  19:00 to 19:59             Wednesday
# 100880           24   01/03/2018    8:00 to 8:59              Thursday
# 100974           17   01/03/2018    8:00 to 8:59              Thursday
# ...             ...          ...             ...                   ...
# 68564            10   02/03/2018    5:00 to 5:59                Friday
# 68760            10   02/03/2018    5:00 to 5:59                Friday
# 68957            10   02/03/2018    5:00 to 5:59                Friday
# 69161            10   02/03/2018    5:00 to 5:59                Friday
# 69361            10   02/03/2018    5:00 to 5:59                Friday
#
#        publish_country                                               tags  \
# 98184           FRANCE                                             [none]
# 99531           FRANCE                                             [none]
# 103725          FRANCE                       performance"|"Extreme Sports
# 100880          FRANCE                                             [none]
# 100974          FRANCE                                             [none]
# ...                ...                                                ...
# 68564               GB  Bad Bunny|"Amorfoda"|"Dura"|"Daddy Yankee"|"Oz...
# 68760               GB  Bad Bunny|"Amorfoda"|"Dura"|"Daddy Yankee"|"Oz...
# 68957               GB  Bad Bunny|"Amorfoda"|"Dura"|"Daddy Yankee"|"Oz...
# 69161               GB  Bad Bunny|"Amorfoda"|"Dura"|"Daddy Yankee"|"Oz...
# 69361               GB  Bad Bunny|"Amorfoda"|"Dura"|"Daddy Yankee"|"Oz...
#
#          views    likes  dislikes  comment_count  comments_disabled  \
# 98184   448753       21         1              4              False
# 99531   448753       22         2              4              False
# 103725  448753        3         0              0              False
# 100880  448753       43         2             14              False
# 100974  448753       43         0              5              False
# ...        ...      ...       ...            ...                ...
# 68564   255413  2618320    134625          92387              False
# 68760   255413  2670723    138334          93834              False
# 68957   255413  2719005    142006          95713              False
# 69161   255413  2768654    145643          97218              False
# 69361   255413  2818771    149275          99380              False
#
#         ratings_disabled  video_error_or_removed
# 98184              False                   False
# 99531              False                   False
# 103725             False                   False
# 100880             False                   False
# 100974             False                   False
# ...                  ...                     ...
# 68564              False                   False
# 68760              False                   False
# 68957              False                   False
# 69161              False                   False
# 69361              False                   False
#
# [161470 rows x 18 columns]

# %% [markdown]
# LIKES - MEDIAN - 5 NHOM

# %%
DFS2 = DFS.sort_values(by='likes', ascending=True)
DF1 = DFS2[:int(len(DFS2)/5)]
DF2 = DFS2[int(len(DFS2)/5):int(len(DFS2)/5)*2]
DF3 = DFS2[int(len(DFS2)/5)*2:int(len(DFS2)/5)*3]
DF4 = DFS2[int(len(DFS2)/5)*3:int(len(DFS2)/5)*4]
DF5 = DFS2[int(len(DFS2)/5)*4:]

DFS2.loc[[i for i in range(0,int(len(DFS2)/5))], 'likes'] = int(DF1['likes'].median())
DFS2.loc[[i for i in range(int(len(DFS2)/5),int(len(DFS2)/5)*2)], 'likes'] = int(DF2['likes'].median())
DFS2.loc[[i for i in range(int(len(DFS2)/5)*2,int(len(DFS2)/5)*3)], 'likes'] = int(DF3['likes'].median())
DFS2.loc[[i for i in range(int(len(DFS2)/5)*3,int(len(DFS2)/5)*4)], 'likes'] = int(DF4['likes'].median())
DFS2.loc[[i for i in range(int(len(DFS2)/5)*4,len(DFS2))], 'likes'] = int(DF5['likes'].median())
DFS2
# Out:
#          index     video_id trending_date  \
# 64625    64625  c0arVTRwytA      18.14.03
# 57537    57537  BhIEIO0vaBE      18.07.02
# 151758  151758  OO8bo_fpoQg      18.27.04
# 16590    16590  BhIEIO0vaBE      18.07.02
# 96473    96473  BhIEIO0vaBE      18.07.02
# ...        ...          ...           ...
# 77237    77237  7C2z4GqqS5E      18.30.05
# 38072    38072  7C2z4GqqS5E      18.31.05
# 77417    77417  7C2z4GqqS5E      18.31.05
# 38273    38273  7C2z4GqqS5E      18.01.06
# 77587    77587  7C2z4GqqS5E      18.01.06
#
#                                                     title  \
# 64625   ã€å…¬å¼ã€‘ã€ŒåŠ‡å ´ç‰ˆãƒã‚±ãƒƒãƒˆãƒ¢ãƒ³ã‚¹ã...
# 57537                                     To Our Daughter
# 151758  åœ†æ¡Œæ´¾S3 ç¬¬21é›† ç»†èŠ‚ é­”é¬¼è—åœ¨ç»†èŠ‚é‡Œ
# 16590                                     To Our Daughter
# 96473                                     To Our Daughter
# ...                                                   ...
# 77237       BTS (ë°©íƒ„ì†Œë…„ë‹¨) 'FAKE LOVE' Official MV
# 38072       BTS (ë°©íƒ„ì†Œë…„ë‹¨) 'FAKE LOVE' Official MV
# 77417       BTS (ë°©íƒ„ì†Œë…„ë‹¨) 'FAKE LOVE' Official MV
# 38273       BTS (ë°©íƒ„ì†Œë…„ë‹¨) 'FAKE LOVE' Official MV
# 77587       BTS (ë°©íƒ„ì†Œë…„ë‹¨) 'FAKE LOVE' Official MV
#
#                                    channel_title  category_id publish_date  \
# 64625   ãƒã‚±ãƒ¢ãƒ³å…¬å¼YouTubeãƒãƒ£ãƒ³ãƒãƒ«            1   27/02/2018
# 57537                               Kylie Jenner           22   04/02/2018
# 151758                                    ä¼˜é…·           24   26/04/2018
# 16590                               Kylie Jenner           22   04/02/2018
# 96473                               Kylie Jenner           22   04/02/2018
# ...                                          ...          ...          ...
# 77237                                    ibighit           10   18/05/2018
# 38072                                    ibighit           10   18/05/2018
# 77417                                    ibighit           10   18/05/2018
# 38273                                    ibighit           10   18/05/2018
# 77587                                    ibighit           10   18/05/2018
#
#             time_frame published_day_of_week publish_country  \
# 64625     1:00 to 1:59               Tuesday              GB
# 57537   20:00 to 20:59                Sunday              GB
# 151758  11:00 to 11:59              Thursday          CANADA
# 16590   20:00 to 20:59                Sunday              US
# 96473   20:00 to 20:59                Sunday          FRANCE
# ...                ...                   ...             ...
# 77237     9:00 to 9:59                Friday              GB
# 38072     9:00 to 9:59                Friday              US
# 77417     9:00 to 9:59                Friday              GB
# 38273     9:00 to 9:59                Friday              US
# 77587     9:00 to 9:59                Friday              GB
#
#                                                      tags   views  likes  \
# 64625   pokemon|"PokÃ©mon"|"ãƒã‚±ãƒ¢ãƒ³"|"ãƒã‚±ãƒƒãƒ...  255413   6084
# 57537   Kylie Jenner|"Kylie"|"Travis Scott"|"Baby"|"An...  122192   2457
# 151758  åœ†æ¡Œæ´¾|"ç»¼è‰º"|"è„±å£ç§€"|"è®¿è°ˆ"|"ç¤¾ä¼...  876654   2457
# 16590   Kylie Jenner|"Kylie""|""Travis Scott""|""Baby"...   27783    328
# 96473   Kylie Jenner"|"Kylie"|"Travis Scott"|"Baby"|"A...  255413   6084
# ...                                                   ...     ...    ...
# 77237   BIGHIT|"ë¹…ížˆíŠ¸"|"ë°©íƒ„ì†Œë…„ë‹¨"|"BTS"|"BA...  255413   6084
# 38072   BIGHIT|"ë¹…ížˆíŠ¸""|""ë°©íƒ„ì†Œë…„ë‹¨""|""BTS"...  122192   2457
# 77417   BIGHIT|"ë¹…ížˆíŠ¸"|"ë°©íƒ„ì†Œë…„ë‹¨"|"BTS"|"BA...  255413   6084
# 38273   BIGHIT|"ë¹…ížˆíŠ¸""|""ë°©íƒ„ì†Œë…„ë‹¨""|""BTS"...  122192   2457
# 77587   BIGHIT|"ë¹…ížˆíŠ¸"|"ë°©íƒ„ì†Œë…„ë‹¨"|"BTS"|"BA...  255413   6084
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 64625          0              0               True              True
# 57537          0              0               True              True
# 151758         0            144              False              True
# 16590          0              0               True              True
# 96473          0              0               True              True
# ...          ...            ...                ...               ...
# 77237     200995        1213172              False             False
# 38072     205565        1225326              False             False
# 77417     205565        1225326              False             False
# 38273     206892        1228655              False             False
# 77587     206892        1228655              False             False
#
#         video_error_or_removed
# 64625                    False
# 57537                    False
# 151758                   False
# 16590                    False
# 96473                    False
# ...                        ...
# 77237                    False
# 38072                    False
# 77417                    False
# 38273                    False
# 77587                    False
#
# [161470 rows x 18 columns]

# %% [markdown]
# DISLIKE - BOUNDARIES - 5 NHOM

# %%
DFS3 = DFS.sort_values(by='dislikes', ascending=True)
DF1 = DFS3[:int(len(DFS3)/5)]
DF2 = DFS3[int(len(DFS3)/5):int(len(DFS3)/5)*2]
DF3 = DFS3[int(len(DFS3)/5)*2:int(len(DFS3)/5)*3]
DF4 = DFS3[int(len(DFS3)/5)*3:int(len(DFS3)/5)*4]
DF5 = DFS3[int(len(DFS3)/5)*4:]

for i in range(0,int(len(DFS3)/5)):
    if i - int(DF1['dislikes'].min()) < int(DF1['dislikes'].max()) - i:
        DFS3.loc[i, 'dislikes'] = int(DF1['dislikes'].min())
    else:
        DFS3.loc[i, 'dislikes'] = int(DF1['dislikes'].max())
for i in range(int(len(DFS3)/5),int(len(DFS3)/5)*2):
    if i - int(DF2['dislikes'].min()) < int(DF2['dislikes'].max()) - i:
        DFS3.loc[i, 'dislikes'] = int(DF2['dislikes'].min())
    else:
        DFS3.loc[i, 'dislikes'] = int(DF2['dislikes'].max())
for i in range(int(len(DFS3)/5)*2,int(len(DFS3)/5)*3):
    if i - int(DF3['dislikes'].min()) < int(DF3['dislikes'].max()) - i:
        DFS3.loc[i, 'dislikes'] = int(DF3['dislikes'].min())
    else:
        DFS3.loc[i, 'dislikes'] = int(DF3['dislikes'].max())
for i in range(int(len(DFS3)/5)*3,int(len(DFS3)/5)*4):
    if i - int(DF4['dislikes'].min()) < int(DF4['dislikes'].max()) - i:
        DFS3.loc[i, 'dislikes'] = int(DF4['dislikes'].min())
    else:
        DFS3.loc[i, 'dislikes'] = int(DF4['dislikes'].max())
for i in range(int(len(DFS3)/5)*4,len(DFS3)):
    if i - int(DF5['dislikes'].min()) < int(DF5['dislikes'].max()) - i:
        DFS3.loc[i, 'dislikes'] = int(DF5['dislikes'].min())
    else:
        DFS3.loc[i, 'dislikes'] = int(DF5['dislikes'].max())
DFS3
# Out:
#          index     video_id trending_date  \
# 108243  108243  qn4fCIcNtms      18.07.04
# 42573    42573  A_Z3AokMwWI      17.22.11
# 98991    98991  8ePLn3VzrIA      18.19.02
# 117835  117835  m7xgwKEI6Vg      18.31.05
# 146071  146071  MmrB_tGZ3JY      18.23.03
# ...        ...          ...           ...
# 52877    52877  QwZT7T-TXT0      18.14.01
# 53083    53083  QwZT7T-TXT0      18.15.01
# 53292    53292  QwZT7T-TXT0      18.16.01
# 53508    53508  QwZT7T-TXT0      18.17.01
# 53733    53733  QwZT7T-TXT0      18.18.01
#
#                                                     title  \
# 108243                          Reco - Paris-Roubaix 2018
# 42573                       MINECON Earth 2017 Livestream
# 98991                     Montage haut moteur Metrakit 70
# 117835  ELISABETH LEVY N'EST PAS CONTENTE que Mamoudou...
# 146071  Maple Leafs Morning Skate: Auston Matthews - M...
# ...                                                   ...
# 52877                                           So Sorry.
# 53083                                           So Sorry.
# 53292                                           So Sorry.
# 53508                                           So Sorry.
# 53733                                           So Sorry.
#
#                     channel_title  category_id publish_date      time_frame  \
# 108243  EquipeCyclisteGroupamaFDJ           17   06/04/2018  14:00 to 14:59
# 42573                  TeamMojang           20   18/11/2017  19:00 to 19:59
# 98991              Tomahawktuning            2   18/02/2018  16:00 to 16:59
# 117835              Paulaclosetfr           24   28/05/2018  18:00 to 18:59
# 146071        Toronto Maple Leafs           17   22/03/2018  17:00 to 17:59
# ...                           ...          ...          ...             ...
# 52877            Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
# 53083            Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
# 53292            Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
# 53508            Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
# 53733            Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 108243                Friday          FRANCE
# 42573               Saturday              GB
# 98991                 Sunday          FRANCE
# 117835                Monday          FRANCE
# 146071              Thursday          CANADA
# ...                      ...             ...
# 52877                Tuesday              GB
# 53083                Tuesday              GB
# 53292                Tuesday              GB
# 53508                Tuesday              GB
# 53733                Tuesday              GB
#
#                                                      tags   views    likes  \
# 108243                                             [none]  448753      124
# 42573            Minecon|"Minecraft"|"Microsoft"|"Mojang"  122192        0
# 98991                                              [none]  448753        0
# 117835  mamoudou gassama|"mamoudou gassama mali 'spide...  448753        0
# 146071  Toronto|"Toronto Maple Leafs"|"Leafs"|"Maple L...  876654       73
# ...                                                   ...     ...      ...
# 52877   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  122192  1515888
# 53083   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  122192  1532248
# 53292   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  122192  1547034
# 53508   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  122192  1559608
# 53733   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  122192  1572111
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 108243      1907              8              False             False
# 42573        210           7033              False              True
# 98991       1907              0               True              True
# 117835      1907           1266              False              True
# 146071    174645             21              False             False
# ...          ...            ...                ...               ...
# 52877        210        1534873              False             False
# 53083        210        1562312              False             False
# 53292        210        1588337              False             False
# 53508        210        1606178              False             False
# 53733        210        1626501              False             False
#
#         video_error_or_removed
# 108243                   False
# 42573                    False
# 98991                    False
# 117835                   False
# 146071                   False
# ...                        ...
# 52877                    False
# 53083                    False
# 53292                    False
# 53508                    False
# 53733                    False
#
# [161470 rows x 18 columns]

# %% [markdown]
# TIM DO LECH CHUAN LON NHAT

# %%
S2 = (DF['likes']**2).sum()
S3 = (DF['dislikes']**2).sum()
S4 = (DF['comment_count']**2).sum()

y = S2 / len(DF) - DF['likes'].mean()**2
z = S3 / len(DF) - DF['dislikes'].mean()**2
t = S4 / len(DF) - DF['comment_count'].mean()**2

variance = sum((DF['views'] - DF['views'].mean())**2) / len(DF)

std_views = variance**0.5
std_likes = y**0.5
std_dislikes = z**0.5
std_comment_count = t**0.5

print(std_views, std_likes, std_dislikes, std_comment_count)

DFS_SORT = DFS.sort_values(by='views', ascending=True)
# Tăng 10% cho 5 giá trị nhỏ nhất
DFS_SORT.iloc[:5, DFS_SORT.columns.get_loc('views')] *= 1.1
# Giảm 10% cho 5 giá trị lớn nhất
DFS_SORT.iloc[-5:, DFS_SORT.columns.get_loc('views')] *= 0.9
DFS_SORT
# Out:
# 10437454.55138843 226060.96911837196 31147.692515021354 34041.108170603766
# C:\Users\minhv\AppData\Local\Temp\ipykernel_10880\3319715071.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[30561.3 30561.3 30561.3 30561.3 30561.3]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   DFS_SORT.iloc[:5, DFS_SORT.columns.get_loc('views')] *= 1.1
#          index     video_id trending_date  \
# 19293    19293       #NAME?      18.20.02
# 26448    26448  9x8JN8zDqis      18.28.03
# 18541    18541  rNaFB-IoXaA      18.16.02
# 26514    26514  9SCNLl0MQPM      18.28.03
# 9257      9257  RsIIT6rXnSM      17.30.12
# ...        ...          ...           ...
# 146324  146324  gjQ1Brofle8      18.25.03
# 137306  137306  OCpilgtSlOE      18.07.02
# 132989  132989  hgimG_9Fh2s      18.17.01
# 137586  137586  b9wJ97_fR54      18.09.02
# 133311  133311  x7Ilf1mAZCk      18.18.01
#
#                                                     title  \
# 19293   Padma Lakshmi On A #TopChefâ€™s Cancer Diagnos...
# 26448                I WENT ON A DATE WITH HER BOYFRIEND!
# 18541                    Kehlani - Again [Official Audio]
# 26514   Apple Announces March 27th Keynote! What To Ex...
# 9257    In-N-Out Vs. Shake Shack Taste Test with Tom S...
# ...                                                   ...
# 146324  ã€ENG SUBå…¨çƒã€‘ã€Šæ­Œæ‰‹2018ã€‹ç¬¬10æœŸ 20...
# 137306         BRO'LASKA with ALASKA & CORY - All Stars 2
# 132989  Ezra Levant: Police need to charge hijab hoax mom
# 137586  Stephen Colbert Monologue 2/7/18: The Pres.Tru...
# 133311  ÐÐ¾Ð²Ð°Ñ Ð Ð¾ÑÑÐ¸Ñ: The Hatters, ÐÐºÑÐµ...
#
#                                             channel_title  category_id  \
# 19293             Watch What Happens Live with Andy Cohen           24
# 26448                                        Gabbie Hanna           26
# 18541                                     kehlani parrish           10
# 26514                                  EverythingApplePro           24
# 9257                                       First We Feast           26
# ...                                                   ...          ...
# 146324  æ¹–å—å«è§†èŠ’æžœTVå®˜æ–¹é¢‘é“ China HunanTV...           24
# 137306                                        WOWPresents           24
# 132989                                        Rebel Media           25
# 137586                                  TRUMP LATEST NEWS           23
# 133311                                         Ð²Ð”ÑƒÐ´ÑŒ           22
#
#        publish_date      time_frame published_day_of_week publish_country  \
# 19293    15/02/2018    4:00 to 4:59              Thursday              US
# 26448    21/03/2018  20:00 to 20:59             Wednesday              US
# 18541    09/02/2018    4:00 to 4:59                Friday              US
# 26514    16/03/2018  18:00 to 18:59                Friday              US
# 9257     26/12/2017  16:00 to 16:59               Tuesday              US
# ...             ...             ...                   ...             ...
# 146324   23/03/2018  17:00 to 17:59                Friday          CANADA
# 137306   06/02/2018  13:00 to 13:59               Tuesday          CANADA
# 132989   15/01/2018  22:00 to 22:59                Monday          CANADA
# 137586   08/02/2018    5:00 to 5:59              Thursday          CANADA
# 133311   17/01/2018  15:00 to 15:59             Wednesday          CANADA
#
#                                                      tags     views   likes  \
# 19293   What What Happens live|"reality""|""interview"...   30561.3     133
# 26448   the gabbie show|"thegabbieshow""|""story time"...   30561.3   50840
# 18541   Kehlani|"Atlantic Records""|""WMG""|""Warner M...   30561.3   32229
# 26514   Apple Event|"Apple Keynote""|""March Keynote""...   30561.3   17263
# 9257    First we feast|"fwf""|""firstwefeast""|""food"...   30561.3   17086
# ...                                                   ...       ...     ...
# 146324  æˆ‘æ˜¯æ­Œæ‰‹|"æ­Œæ‰‹"|"æ­Œæ‰‹2018"|"æ±ªå³°"|"å...  788988.6    3618
# 137306  world of wonder|"world of wonder productions"|...  788988.6    3626
# 132989  news|"Rebel Media"|"RebelMedia"|"ezra levant"|...  788988.6    3706
# 137586                                             [none]  788988.6     732
# 133311  thehatters|"hatters"|"gipsyrock"|"gipsypunk"|"...  788988.6  110395
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 19293         33             24              False             False
# 26448       4011           6155              False             False
# 18541        420           1364              False             False
# 26514        588           1790              False             False
# 9257         599           3238              False             False
# ...          ...            ...                ...               ...
# 146324       503           3632              False             False
# 137306        50            393              False             False
# 132989       234           1874              False             False
# 137586       168            194              False             False
# 133311      4952           9793              False             False
#
#         video_error_or_removed
# 19293                    False
# 26448                    False
# 18541                    False
# 26514                    False
# 9257                     False
# ...                        ...
# 146324                   False
# 137306                   False
# 132989                   False
# 137586                   False
# 133311                   False
#
# [161470 rows x 18 columns]

# %% [markdown]
# XAC DINH GIA TRI NGOAI LE

# %% [markdown]
# VIEWS

# %%
DFSV = DF.sort_values(by='views', ascending=True)
Q1 = DFSV.iloc[int(len(DF)*0.25)]['views']
Q3 = DFSV.iloc[int(len(DF)*0.75)]['views']

OL_Views = DFSV[(DFSV['views'] < Q1 - (1.5 * (Q3 - Q1))) | (DFSV['views'] > Q3 + (1.5 * (Q3 - Q1)))]
OL_Views
# Out:
#          index     video_id trending_date  \
# 59482    59482  61G3tDZQNhg      18.16.02
# 76171    76171  p1DAEZNyJ8E      18.23.05
# 4274      4274  fEskVQgtwaI      17.05.12
# 41223    41223  A8ScwhLh7uo      17.15.11
# 154108  154108  Kc6CIwBVo5s      18.09.05
# ...        ...          ...           ...
# 68564    68564  _I_D_8Z4sJE      18.03.04
# 68760    68760  _I_D_8Z4sJE      18.04.04
# 68957    68957  _I_D_8Z4sJE      18.05.04
# 69161    69161  _I_D_8Z4sJE      18.06.04
# 69361    69361  _I_D_8Z4sJE      18.07.04
#
#                                                     title  \
# 59482   Ronda Rousey confronts Asuka, Alexa Bliss and ...
# 76171         Avengers: Infinity War | Marvel Family Feud
# 4274    Midnight Sun | Official Trailer | In Theaters ...
# 41223                   Honest Trailers - Stranger Things
# 154108     Hawaiian lava flows â€˜faster than a turtleâ€™
# ...                                                   ...
# 68564   Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...
# 68760   Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...
# 68957   Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...
# 69161   Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...
# 69361   Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...
#
#                 channel_title  category_id publish_date      time_frame  \
# 59482                     WWE           17   29/01/2018    4:00 to 4:59
# 76171   Marvel Studios Movies           29   22/04/2018  23:00 to 23:59
# 4274          Open Road Films           24   01/12/2017  18:00 to 18:59
# 41223          Screen Junkies            1   07/11/2017  18:00 to 18:59
# 154108   ABC News (Australia)           25   07/05/2018  22:00 to 22:59
# ...                       ...          ...          ...             ...
# 68564              NickyJamTV           10   02/03/2018    5:00 to 5:59
# 68760              NickyJamTV           10   02/03/2018    5:00 to 5:59
# 68957              NickyJamTV           10   02/03/2018    5:00 to 5:59
# 69161              NickyJamTV           10   02/03/2018    5:00 to 5:59
# 69361              NickyJamTV           10   02/03/2018    5:00 to 5:59
#
#        published_day_of_week publish_country  \
# 59482                 Monday              GB
# 76171                 Sunday              GB
# 4274                  Friday              US
# 41223                Tuesday              GB
# 154108                Monday          CANADA
# ...                      ...             ...
# 68564                 Friday              GB
# 68760                 Friday              GB
# 68957                 Friday              GB
# 69161                 Friday              GB
# 69361                 Friday              GB
#
#                                                      tags      views    likes  \
# 59482   wwe|"world wrestling entertainment"|"wrestling...    3196632    29304
# 76171   Avengers: Infinity War|"Avengers"|"scarlett jo...    3197227    67693
# 4274    midnight sun|"movie""|""trailer""|""new traile...    3197543     7511
# 41223   screenjunkies|"screen junkies"|"honest trailer...    3197694    93970
# 154108  Australia|"Kilauea"|"Hawai'i"|"Hawaii"|"Leilan...    3197699    20967
# ...                                                   ...        ...      ...
# 68564   Bad Bunny|"Amorfoda"|"Dura"|"Daddy Yankee"|"Oz...  382401497  2618320
# 68760   Bad Bunny|"Amorfoda"|"Dura"|"Daddy Yankee"|"Oz...  392036878  2670723
# 68957   Bad Bunny|"Amorfoda"|"Dura"|"Daddy Yankee"|"Oz...  402650804  2719005
# 69161   Bad Bunny|"Amorfoda"|"Dura"|"Daddy Yankee"|"Oz...  413586699  2768654
# 69361   Bad Bunny|"Amorfoda"|"Dura"|"Daddy Yankee"|"Oz...  424538912  2818771
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 59482       2651           6884              False             False
# 76171       1248           6295              False             False
# 4274         525            933              False             False
# 41223       2820           7325              False             False
# 154108      1626              0               True             False
# ...          ...            ...                ...               ...
# 68564     134625          92387              False             False
# 68760     138334          93834              False             False
# 68957     142006          95713              False             False
# 69161     145643          97218              False             False
# 69361     149275          99380              False             False
#
#         video_error_or_removed
# 59482                    False
# 76171                    False
# 4274                     False
# 41223                    False
# 154108                   False
# ...                        ...
# 68564                    False
# 68760                    False
# 68957                    False
# 69161                    False
# 69361                    False
#
# [20446 rows x 18 columns]

# %% [markdown]
# LIKES

# %%
DFSL = DF.sort_values(by='likes', ascending=True)
Q1 = DFSL.iloc[int(len(DF)*0.25)]['likes']
Q3 = DFSL.iloc[int(len(DF)*0.75)]['likes']

OL_Likes = DFSL[(DFSL['likes'] < Q1 - (1.5 * (Q3 - Q1))) | (DFSL['likes'] > Q3 + (1.5 * (Q3 - Q1)))]
OL_Likes
# Out:
#          index     video_id trending_date  \
# 149776  149776  xCY9B8POq3A      18.17.04
# 148279  148279  Oh4kio5hYn8      18.03.04
# 31206    31206  MWbQdgjsvJI      18.27.04
# 78779    78779  N1HAMUAXzbs      18.08.06
# 54613    54613  X6SaVOLRcF4      18.23.01
# ...        ...          ...           ...
# 37861    37861  7C2z4GqqS5E      18.30.05
# 38072    38072  7C2z4GqqS5E      18.31.05
# 77417    77417  7C2z4GqqS5E      18.31.05
# 38273    38273  7C2z4GqqS5E      18.01.06
# 77587    77587  7C2z4GqqS5E      18.01.06
#
#                                                     title   channel_title  \
# 149776                                      mirror selfie     SethEverman
# 148279  Shawn Mendes Reveals a New Side of Himself Whi...  First We Feast
# 31206                   MAKING A DRESS OUT OF TRASH BAGS!    Amber Scholl
# 78779        Kris Wu â€“ Like That (Official Music Video)         Kris Wu
# 54613   Famous Dex - Pick It Up feat. A$AP Rocky [Offi...      Famous Dex
# ...                                                   ...             ...
# 37861       BTS (ë°©íƒ„ì†Œë…„ë‹¨) 'FAKE LOVE' Official MV         ibighit
# 38072       BTS (ë°©íƒ„ì†Œë…„ë‹¨) 'FAKE LOVE' Official MV         ibighit
# 77417       BTS (ë°©íƒ„ì†Œë…„ë‹¨) 'FAKE LOVE' Official MV         ibighit
# 38273       BTS (ë°©íƒ„ì†Œë…„ë‹¨) 'FAKE LOVE' Official MV         ibighit
# 77587       BTS (ë°©íƒ„ì†Œë…„ë‹¨) 'FAKE LOVE' Official MV         ibighit
#
#         category_id publish_date      time_frame published_day_of_week  \
# 149776           24   13/04/2018  21:00 to 21:59                Friday
# 148279           26   29/03/2018  15:00 to 15:59              Thursday
# 31206            26   22/04/2018  15:00 to 15:59                Sunday
# 78779            10   22/05/2018  15:00 to 15:59               Tuesday
# 54613            10   17/01/2018  17:00 to 17:59             Wednesday
# ...             ...          ...             ...                   ...
# 37861            10   18/05/2018    9:00 to 9:59                Friday
# 38072            10   18/05/2018    9:00 to 9:59                Friday
# 77417            10   18/05/2018    9:00 to 9:59                Friday
# 38273            10   18/05/2018    9:00 to 9:59                Friday
# 77587            10   18/05/2018    9:00 to 9:59                Friday
#
#        publish_country                                               tags  \
# 149776          CANADA  seth|"everman"|"setheverman"|"piano"|"eyebrows...
# 148279          CANADA  First we feast|"fwf"|"firstwefeast"|"food"|"fo...
# 31206               US  DIY|"trash""|""how to""|""dress""|""tutorial""...
# 78779               GB  Kris Wu|"Wu Yi Fan"|"å´äº¦å‡¡"|"fan shi"|"wuy...
# 54613               GB  Famous|"Dex"|"Famous Dex"|"Dexter Official"|"n...
# ...                ...                                                ...
# 37861               US  BIGHIT|"ë¹…ížˆíŠ¸""|""ë°©íƒ„ì†Œë…„ë‹¨""|""BTS"...
# 38072               US  BIGHIT|"ë¹…ížˆíŠ¸""|""ë°©íƒ„ì†Œë…„ë‹¨""|""BTS"...
# 77417               GB  BIGHIT|"ë¹…ížˆíŠ¸"|"ë°©íƒ„ì†Œë…„ë‹¨"|"BTS"|"BA...
# 38273               US  BIGHIT|"ë¹…ížˆíŠ¸""|""ë°©íƒ„ì†Œë…„ë‹¨""|""BTS"...
# 77587               GB  BIGHIT|"ë¹…ížˆíŠ¸"|"ë°©íƒ„ì†Œë…„ë‹¨"|"BTS"|"BA...
#
#             views    likes  dislikes  comment_count  comments_disabled  \
# 149776    1118554    97211       738           4708              False
# 148279    1896573    97215      1357           9406              False
# 31206     1439093    97217      1578           7321              False
# 78779    13404676    97221         0          10442              False
# 54613     3113052    97222      1219           4757              False
# ...           ...      ...       ...            ...                ...
# 37861   115664850  5530568    200995        1213172              False
# 38072   121219886  5595203    205565        1225326              False
# 77417   121219886  5595203    205565        1225326              False
# 38273   123010920  5613827    206892        1228655              False
# 77587   123010920  5613827    206892        1228655              False
#
#         ratings_disabled  video_error_or_removed
# 149776             False                   False
# 148279             False                   False
# 31206              False                   False
# 78779              False                   False
# 54613              False                   False
# ...                  ...                     ...
# 37861              False                   False
# 38072              False                   False
# 77417              False                   False
# 38273              False                   False
# 77587              False                   False
#
# [22428 rows x 18 columns]

# %% [markdown]
# DISLIKES

# %%
DFSDL = DF.sort_values(by='dislikes', ascending=True)
Q1 = DFSDL.iloc[int(len(DF)*0.25)]['dislikes']
Q3 = DFSDL.iloc[int(len(DF)*0.75)]['dislikes']

OL_DL = DFSDL[(DFSDL['dislikes'] < Q1 - (1.5 * (Q3 - Q1))) | (DFSDL['dislikes'] > Q3 + (1.5 * (Q3 - Q1)))]
OL_DL
# Out:
#          index     video_id trending_date  \
# 57804    57804  J6-8DQALGt4      18.08.02
# 65496    65496  rgqU0MbRLDo      18.18.03
# 41571    41571  A5TPOKoE1_M      17.17.11
# 144405  144405  0HX039UdGpU      18.15.03
# 44066    44066  tz23WFb8HM0      17.29.11
# ...        ...          ...           ...
# 52877    52877  QwZT7T-TXT0      18.14.01
# 53083    53083  QwZT7T-TXT0      18.15.01
# 53292    53292  QwZT7T-TXT0      18.16.01
# 53508    53508  QwZT7T-TXT0      18.17.01
# 53733    53733  QwZT7T-TXT0      18.18.01
#
#                                                     title  \
# 57804   Alexa Loses Her Voice â€“ Amazon Super Bowl LI...
# 65496   Black Panther; COMPREHENSIVE REVIEW [no spoilers]
# 41571                      CHRISTMAS ADVERTS & HOW WE MET
# 144405                                  EVERY TARGET EVER
# 44066                               [MV] KARD _ You In Me
# ...                                                   ...
# 52877                                           So Sorry.
# 53083                                           So Sorry.
# 53292                                           So Sorry.
# 53508                                           So Sorry.
# 53733                                           So Sorry.
#
#                channel_title  category_id publish_date      time_frame  \
# 57804                 amazon           24   31/01/2018  13:00 to 13:59
# 65496           CaseyNeistat           22   13/02/2018  14:00 to 14:59
# 41571             MoreZoella           22   14/11/2017  21:00 to 21:59
# 144405                 Smosh           23   12/03/2018  16:00 to 16:59
# 44066   1theK (ì›ë”ì¼€ì´)           10   21/11/2017    9:00 to 9:59
# ...                      ...          ...          ...             ...
# 52877       Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
# 53083       Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
# 53292       Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
# 53508       Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
# 53733       Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 57804              Wednesday              GB
# 65496                Tuesday              GB
# 41571                Tuesday              GB
# 144405                Monday          CANADA
# 44066                Tuesday              GB
# ...                      ...             ...
# 52877                Tuesday              GB
# 53083                Tuesday              GB
# 53292                Tuesday              GB
# 53508                Tuesday              GB
# 53733                Tuesday              GB
#
#                                                      tags     views    likes  \
# 57804   super bowl|"super bowl commercial"|"amazon"|"a...  41419058   112777
# 65496   black panther review|"akilah hughes"|"casey ne...   1544433    56402
# 41571   zoe sugg|"zoella"|"zoe"|"vlog"|"vlogging"|"vlo...   1285196    63951
# 144405  every blank ever|"every shopper ever"|"every s...   1671521    48592
# 44066   Kpop|"1theK"|"ì›ë”ì¼€ì´"|"loen"|"ë¡œì—”"|"ë...   4033960   308676
# ...                                                   ...       ...      ...
# 52877   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  42829793  1515888
# 53083   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  43596655  1532248
# 53292   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  44266614  1547034
# 53508   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  44815907  1559608
# 53733   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  45349447  1572111
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 57804       3248           7647              False             False
# 65496       3248           6031              False             False
# 41571       3249            301              False             False
# 144405      3250           3827              False             False
# 44066       3250          16691              False             False
# ...          ...            ...                ...               ...
# 52877    1868756        1534873              False             False
# 53083    1890743        1562312              False             False
# 53292    1911836        1588337              False             False
# 53508    1928677        1606178              False             False
# 53733    1944971        1626501              False             False
#
#         video_error_or_removed
# 57804                    False
# 65496                    False
# 41571                    False
# 144405                   False
# 44066                    False
# ...                        ...
# 52877                    False
# 53083                    False
# 53292                    False
# 53508                    False
# 53733                    False
#
# [21963 rows x 18 columns]

# %% [markdown]
# COMMENT_COUNT

# %%
DFSCC = DF.sort_values(by='comment_count', ascending=True)
Q1 = DFSCC.iloc[int(len(DF)*0.25)]['comment_count']
Q3 = DFSCC.iloc[int(len(DF)*0.75)]['comment_count']

OL_CC = DFSCC[(DFSCC['comment_count'] < Q1 - (1.5 * (Q3 - Q1))) | (DFSCC['comment_count'] > Q3 + (1.5 * (Q3 - Q1)))]
OL_CC
# Out:
#          index     video_id trending_date  \
# 67059    67059  9XaS93WMRQQ      18.26.03
# 52082    52082  tLOl3s0uIM4      18.08.01
# 130075  130075  eUd6Z_zyXZM      17.31.12
# 44211    44211  e5IRkF20JmU      17.30.11
# 3277      3277  e5IRkF20JmU      17.30.11
# ...        ...          ...           ...
# 52877    52877  QwZT7T-TXT0      18.14.01
# 53083    53083  QwZT7T-TXT0      18.15.01
# 53292    53292  QwZT7T-TXT0      18.16.01
# 53508    53508  QwZT7T-TXT0      18.17.01
# 53733    53733  QwZT7T-TXT0      18.18.01
#
#                                                     title  \
# 67059                Bad Wolves - Zombie (Official Video)
# 52082   J Balvin, Jowell & Randy - Bonita (Remix) ft. ...
# 130075  REAL CONVERSATIONS: Iâ€™m Pro-Life (2nd Editio...
# 44211                      REACTING to BTS Mic Drop! (MV)
# 3277                       REACTING to BTS Mic Drop! (MV)
# ...                                                   ...
# 52877                                           So Sorry.
# 53083                                           So Sorry.
# 53292                                           So Sorry.
# 53508                                           So Sorry.
# 53733                                           So Sorry.
#
#               channel_title  category_id publish_date      time_frame  \
# 67059    Eleven Seven Music           10   22/02/2018  15:00 to 15:59
# 52082           jbalvinVEVO           10   22/12/2017    5:00 to 5:59
# 130075        StevenCrowder           23   29/12/2017  16:00 to 16:59
# 44211   Wassabi Productions           24   27/11/2017  23:00 to 23:59
# 3277    Wassabi Productions           24   27/11/2017  23:00 to 23:59
# ...                     ...          ...          ...             ...
# 52877      Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
# 53083      Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
# 53292      Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
# 53508      Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
# 53733      Logan Paul Vlogs           24   02/01/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 67059               Thursday              GB
# 52082                 Friday              GB
# 130075                Friday          CANADA
# 44211                 Monday              GB
# 3277                  Monday              US
# ...                      ...             ...
# 52877                Tuesday              GB
# 53083                Tuesday              GB
# 53292                Tuesday              GB
# 53508                Tuesday              GB
# 53733                Tuesday              GB
#
#                                                      tags     views    likes  \
# 67059   Bad Wolves|"Bad Wolves Zombie"|"Bad Wolves Toa...  16760709   261807
# 52082   Balvin|"Jowell"|"Randy"|"Bonita"|"Rimas"|"(J"|...  13856380   245814
# 130075  steven crowder|"stephen crowder"|"louder with ...    285648    18669
# 44211   Wassabi|"Alex Wassabi"|"Wassabi Productions"|"...    424563    24842
# 3277    Wassabi|"Alex Wassabi""|""Wassabi Productions"...    424563    24842
# ...                                                   ...       ...      ...
# 52877   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  42829793  1515888
# 53083   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  43596655  1532248
# 53292   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  44266614  1547034
# 53508   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  44815907  1559608
# 53733   logan paul vlog|"logan paul"|"logan"|"paul"|"o...  45349447  1572111
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 67059       8628           9945              False             False
# 52082      12767           9945              False             False
# 130075       296           9946              False             False
# 44211        479           9946              False             False
# 3277         479           9946              False             False
# ...          ...            ...                ...               ...
# 52877    1868756        1534873              False             False
# 53083    1890743        1562312              False             False
# 53292    1911836        1588337              False             False
# 53508    1928677        1606178              False             False
# 53733    1944971        1626501              False             False
#
#         video_error_or_removed
# 67059                    False
# 52082                    False
# 130075                   False
# 44211                    False
# 3277                     False
# ...                        ...
# 52877                    False
# 53083                    False
# 53292                    False
# 53508                    False
# 53733                    False
#
# [21431 rows x 18 columns]

# %% [markdown]
# XU LY DU LIEU KHONG NHAT QUAN

# %% [markdown]
# NGAY THANG NAM

# %% [markdown]
# CHU DONG DIEN LOI KHONG NHAT QUAN - trending_date

# %%
DF
YT_Table.loc[[i for i in range(0,5)], 'trending_date'] = '17.14.111'
YT_Table.loc[[i for i in range(5,10)], 'trending_date'] = '17.144.11'
YT_Table.loc[[i for i in range(10,15)], 'trending_date'] = '177.14.11'
YT_Table.loc[[i for i in range(15,20)], 'trending_date'] = '11.14.17'
YT_Table.loc[[i for i in range(20,25)], 'trending_date'] = '14.11.17'
DF
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE     17.14.111
# 1            1  1ZAPwfrtAFY     17.14.111
# 2            2  5qpjK5DgCt4     17.14.111
# 3            3  puqaWrEC7tY     17.14.111
# 4            4  d380meD0W0M     17.14.111
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags    views   likes  \
# 0                                         SHANtell martin   748374   57527
# 1       last week tonight trump presidency|"last week ...  2418783   97185
# 2       racist superman|"rudy""|""mancuso""|""king""|"...  3191434  146033
# 3       rhett and link|"gmm""|""good mythical morning"...   343168   10172
# 4       ryan|"higa""|""higatv""|""nigahiga""|""i dare ...  2095731  132235
# ...                                                   ...      ...     ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685    1701
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339     460
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347   25900
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225    2115
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392     300
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0           2966          15954              False             False
# 1           6146          12703              False             False
# 2           5339           8181              False             False
# 3            666           2146              False             False
# 4           1989          17518              False             False
# ...          ...            ...                ...               ...
# 161465        99           1312              False             False
# 161466        66             51              False             False
# 161467       224           3881              False             False
# 161468       182           1672              False             False
# 161469        62            251              False             False
#
#         video_error_or_removed
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 161465                   False
# 161466                   False
# 161467                   False
# 161468                   False
# 161469                   False
#
# [161470 rows x 18 columns]

# %% [markdown]
# 17.14.111 | 17.144.11 | 177.14.11 | 11.14.17 | 14.11.17 -> 17.14.11

# %%
DF.loc[(DF['trending_date'] == '17.14.111') | (DF['trending_date'] == '17.144.11') | (DF['trending_date'] == '177.14.11') | (DF['trending_date'] == '11.14.17') | (DF['trending_date'] == '14.11.17'), 'trending_date'] = '17.14.11'

# %% [markdown]
# DONG BO trending_date (yy.dd.mm) -> publish_date(dd/mm/yyyy)

# %%
def convert_date(date_str):
    year, day, month = date_str.split('.')
    year = '20' + year  
    return f'{day}/{month}/{year}'

DF['trending_date'] = DF['trending_date'].apply(convert_date)

# %% [markdown]
# FIELD DANH NGHIA

# %% [markdown]
# published_day_of_week, publish_country

# %%
YT_Table.loc[[i for i in range(8,13)], 'published_day_of_week'] = 'MONDAYY'
YT_Table.loc[[i for i in range(0,5)], 'publish_country'] = 'uss'

# %% [markdown]
# MONDAYY -> Monday, uss -> US

# %%
valid_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

DF.loc[~DF['published_day_of_week'].isin(valid_days), 'published_day_of_week'] = DF['published_day_of_week'].str.title()
    
import re

def correct_day(day):
    if day in valid_days:
        return day
    corrected_day = re.sub(r'(\w)\1+', r'\1', day)
    return corrected_day if corrected_day in valid_days else day.lower()

DF['published_day_of_week'] = DF['published_day_of_week'].apply(correct_day)

# %%
valid_countrys = ['US', 'FRANCE', 'CANADA', 'GB']

DF.loc[~DF['publish_country'].isin(valid_days), 'publish_country'] = DF['publish_country'].str.upper()
    
def correct_country(country):
    if country in valid_countrys:
        return country
    corrected_country = re.sub(r'(\w)\1+', r'\1', country)
    return corrected_country if corrected_country in valid_countrys else country.lower()

DF['publish_country'] = DF['publish_country'].apply(correct_country)

# %% [markdown]
# CHUYEN DOI VA PHAN TACH DU LIEU

# %%
id_day = 1
