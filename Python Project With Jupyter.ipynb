# %% [markdown]
# DATA CLEANING

# %%
import pandas as pd
import numpy as np
import csv
import random

YT_Table = pd.read_csv('E:\Data Analysis Basic Method\Project\Data-Analysis-Basic-Method\Dataset5\Youtube_Test.csv')
YT_Table
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\minhv\AppData\Local\Temp\ipykernel_336\2443522030.py:6: SyntaxWarning: invalid escape sequence '\D'
#   YT_Table = pd.read_csv('E:\Data Analysis Basic Method\Project\Data-Analysis-Basic-Method\Dataset5\Youtube_Test.csv')
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags    views   likes  \
# 0                                         SHANtell martin   748374   57527
# 1       last week tonight trump presidency|"last week ...  2418783   97185
# 2       racist superman|"rudy""|""mancuso""|""king""|"...  3191434  146033
# 3       rhett and link|"gmm""|""good mythical morning"...   343168   10172
# 4       ryan|"higa""|""higatv""|""nigahiga""|""i dare ...  2095731  132235
# ...                                                   ...      ...     ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685    1701
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339     460
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347   25900
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225    2115
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392     300
#
#         dislikes  comment_count  comments_disabled  ratings_disabled  \
# 0           2966          15954              False             False
# 1           6146          12703              False             False
# 2           5339           8181              False             False
# 3            666           2146              False             False
# 4           1989          17518              False             False
# ...          ...            ...                ...               ...
# 161465        99           1312              False             False
# 161466        66             51              False             False
# 161467       224           3881              False             False
# 161468       182           1672              False             False
# 161469        62            251              False             False
#
#         video_error_or_removed
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 161465                   False
# 161466                   False
# 161467                   False
# 161468                   False
# 161469                   False
#
# [161470 rows x 18 columns]

# %% [markdown]
# KIEM TRA DU LIEU NULL

# %%
TBN = YT_Table[(YT_Table['video_id'].isnull()) | (YT_Table['trending_date'].isnull()) | (YT_Table['title'].isnull()) | (YT_Table['channel_title'].isnull()) | (YT_Table['category_id'].isnull()) | (YT_Table['publish_date'].isnull()) | (YT_Table['time_frame'].isnull()) | (YT_Table['published_day_of_week'].isnull()) | (YT_Table['publish_country'].isnull()) | (YT_Table['tags'].isnull()) | (YT_Table['views'].isnull()) | (YT_Table['likes'].isnull()) | (YT_Table['dislikes'].isnull()) | (YT_Table['comment_count'].isnull()) | (YT_Table['comments_disabled'].isnull()) | (YT_Table['ratings_disabled'].isnull()) | (YT_Table['video_error_or_removed'].isnull())]
TBN
# Out:
#    index     video_id trending_date  \
# 0      0  2kyS6SvSYSE      17.14.11
# 1      1  1ZAPwfrtAFY      17.14.11
# 2      2  5qpjK5DgCt4      17.14.11
# 3      3  puqaWrEC7tY      17.14.11
# 4      4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id publish_date      time_frame published_day_of_week  \
# 0           22   13/11/2017  17:00 to 17:59                Monday
# 1           24   13/11/2017    7:00 to 7:59                Monday
# 2           23   12/11/2017  19:00 to 19:59                Sunday
# 3           24   13/11/2017  11:00 to 11:59                Monday
# 4           24   12/11/2017  18:00 to 18:59                Sunday
#
#   publish_country tags    views   likes  dislikes  comment_count  \
# 0              US  NaN   748374   57527      2966          15954
# 1              US  NaN  2418783   97185      6146          12703
# 2              US  NaN  3191434  146033      5339           8181
# 3              US  NaN   343168   10172       666           2146
# 4              US  NaN  2095731  132235      1989          17518
#
#    comments_disabled  ratings_disabled  video_error_or_removed
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False

# %% [markdown]
# CHU DONG XOA DU LIEU TREN CAC FIELDS

# %% [markdown]
# 1. TAGS

# %%
YT_Table.loc[[i for i in range(0,5)], 'tags'] = np.nan
YT_Table
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count comments_disabled ratings_disabled  \
# 0        57527.0    2966.0        15954.0             False            False
# 1        97185.0    6146.0        12703.0             False            False
# 2       146033.0    5339.0         8181.0             False            False
# 3        10172.0     666.0         2146.0             False            False
# 4       132235.0    1989.0        17518.0             False            False
# ...          ...       ...            ...               ...              ...
# 161465    1701.0      99.0         1312.0             False            False
# 161466     460.0      66.0           51.0             False            False
# 161467   25900.0     224.0         3881.0             False            False
# 161468    2115.0     182.0         1672.0             False            False
# 161469     300.0      62.0          251.0             False            False
#
#        video_error_or_removed
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 161465                  False
# 161466                  False
# 161467                  False
# 161468                  False
# 161469                  False
#
# [161470 rows x 18 columns]

# %% [markdown]
# 2. VIEWS

# %%
YT_Table.loc[[i for i in range(5,9)], 'views'] = np.nan
YT_Table
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count comments_disabled ratings_disabled  \
# 0        57527.0    2966.0        15954.0             False            False
# 1        97185.0    6146.0        12703.0             False            False
# 2       146033.0    5339.0         8181.0             False            False
# 3        10172.0     666.0         2146.0             False            False
# 4       132235.0    1989.0        17518.0             False            False
# ...          ...       ...            ...               ...              ...
# 161465    1701.0      99.0         1312.0             False            False
# 161466     460.0      66.0           51.0             False            False
# 161467   25900.0     224.0         3881.0             False            False
# 161468    2115.0     182.0         1672.0             False            False
# 161469     300.0      62.0          251.0             False            False
#
#        video_error_or_removed
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 161465                  False
# 161466                  False
# 161467                  False
# 161468                  False
# 161469                  False
#
# [161470 rows x 18 columns]

# %% [markdown]
# 3. LIKES

# %%
YT_Table.loc[[i for i in range(9, 15)], 'likes'] = np.nan
YT_Table
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count comments_disabled ratings_disabled  \
# 0        57527.0    2966.0        15954.0             False            False
# 1        97185.0    6146.0        12703.0             False            False
# 2       146033.0    5339.0         8181.0             False            False
# 3        10172.0     666.0         2146.0             False            False
# 4       132235.0    1989.0        17518.0             False            False
# ...          ...       ...            ...               ...              ...
# 161465    1701.0      99.0         1312.0             False            False
# 161466     460.0      66.0           51.0             False            False
# 161467   25900.0     224.0         3881.0             False            False
# 161468    2115.0     182.0         1672.0             False            False
# 161469     300.0      62.0          251.0             False            False
#
#        video_error_or_removed
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 161465                  False
# 161466                  False
# 161467                  False
# 161468                  False
# 161469                  False
#
# [161470 rows x 18 columns]

# %% [markdown]
# 4. DISLIKES

# %%
YT_Table.loc[[i for i in range(15, 20)], 'dislikes'] = np.nan
YT_Table
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count comments_disabled ratings_disabled  \
# 0        57527.0    2966.0        15954.0             False            False
# 1        97185.0    6146.0        12703.0             False            False
# 2       146033.0    5339.0         8181.0             False            False
# 3        10172.0     666.0         2146.0             False            False
# 4       132235.0    1989.0        17518.0             False            False
# ...          ...       ...            ...               ...              ...
# 161465    1701.0      99.0         1312.0             False            False
# 161466     460.0      66.0           51.0             False            False
# 161467   25900.0     224.0         3881.0             False            False
# 161468    2115.0     182.0         1672.0             False            False
# 161469     300.0      62.0          251.0             False            False
#
#        video_error_or_removed
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 161465                  False
# 161466                  False
# 161467                  False
# 161468                  False
# 161469                  False
#
# [161470 rows x 18 columns]

# %% [markdown]
# 5. COMMENT COUNTS

# %%
YT_Table.loc[[i for i in range(20, 25)], 'comment_count'] = np.nan

# %% [markdown]
# 6. COMMENTS DISABLED

# %%
YT_Table.loc[[i for i in range(25, 30)], 'comments_disabled'] = np.nan
YT_Table
# Out:
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count comments_disabled ratings_disabled  \
# 0        57527.0    2966.0        15954.0             False            False
# 1        97185.0    6146.0        12703.0             False            False
# 2       146033.0    5339.0         8181.0             False            False
# 3        10172.0     666.0         2146.0             False            False
# 4       132235.0    1989.0        17518.0             False            False
# ...          ...       ...            ...               ...              ...
# 161465    1701.0      99.0         1312.0             False            False
# 161466     460.0      66.0           51.0             False            False
# 161467   25900.0     224.0         3881.0             False            False
# 161468    2115.0     182.0         1672.0             False            False
# 161469     300.0      62.0          251.0             False            False
#
#        video_error_or_removed
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 161465                  False
# 161466                  False
# 161467                  False
# 161468                  False
# 161469                  False
#
# [161470 rows x 18 columns]

# %% [markdown]
# 7. RATINGS DISABLED

# %%
YT_Table.loc[[i for i in range(30, 35)], 'ratings_disabled'] = np.nan

# %% [markdown]
# 8. VIDEO ERROR OR REMOVED

# %%
YT_Table.loc[[i for i in range(35, 40)], 'video_error_or_removed'] = np.nan

# %% [markdown]
# DIEN GIA TRI CON THIEU

# %% [markdown]
# VIEWS

# %%
DF = pd.DataFrame(YT_Table)
MMM = [int(DF['views'].mean()), int(DF['views'].mode()[0]), int(DF['views'].median())]
DF['views'].fillna(min(MMM), inplace=True)
DF
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_336\4111462111.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   DF['views'].fillna(min(MMM), inplace=True)
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count comments_disabled ratings_disabled  \
# 0        57527.0    2966.0        15954.0             False            False
# 1        97185.0    6146.0        12703.0             False            False
# 2       146033.0    5339.0         8181.0             False            False
# 3        10172.0     666.0         2146.0             False            False
# 4       132235.0    1989.0        17518.0             False            False
# ...          ...       ...            ...               ...              ...
# 161465    1701.0      99.0         1312.0             False            False
# 161466     460.0      66.0           51.0             False            False
# 161467   25900.0     224.0         3881.0             False            False
# 161468    2115.0     182.0         1672.0             False            False
# 161469     300.0      62.0          251.0             False            False
#
#        video_error_or_removed
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 161465                  False
# 161466                  False
# 161467                  False
# 161468                  False
# 161469                  False
#
# [161470 rows x 18 columns]

# %% [markdown]
# LIKES

# %%
MMM = [int(DF['likes'].mean()), int(DF['likes'].mode()[0]), int(DF['likes'].median())]
DF['likes'].fillna(min(MMM), inplace=True)
DF
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_336\2050711628.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   DF['likes'].fillna(min(MMM), inplace=True)
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count comments_disabled ratings_disabled  \
# 0        57527.0    2966.0        15954.0             False            False
# 1        97185.0    6146.0        12703.0             False            False
# 2       146033.0    5339.0         8181.0             False            False
# 3        10172.0     666.0         2146.0             False            False
# 4       132235.0    1989.0        17518.0             False            False
# ...          ...       ...            ...               ...              ...
# 161465    1701.0      99.0         1312.0             False            False
# 161466     460.0      66.0           51.0             False            False
# 161467   25900.0     224.0         3881.0             False            False
# 161468    2115.0     182.0         1672.0             False            False
# 161469     300.0      62.0          251.0             False            False
#
#        video_error_or_removed
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 161465                  False
# 161466                  False
# 161467                  False
# 161468                  False
# 161469                  False
#
# [161470 rows x 18 columns]

# %% [markdown]
# DISLIKES

# %%
MMM = [int(DF['dislikes'].mean()), int(DF['dislikes'].mode()[0]), int(DF['dislikes'].median())]
DF['dislikes'].fillna(min(MMM), inplace=True)
DF
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_336\2439982794.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   DF['dislikes'].fillna(min(MMM), inplace=True)
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count comments_disabled ratings_disabled  \
# 0        57527.0    2966.0        15954.0             False            False
# 1        97185.0    6146.0        12703.0             False            False
# 2       146033.0    5339.0         8181.0             False            False
# 3        10172.0     666.0         2146.0             False            False
# 4       132235.0    1989.0        17518.0             False            False
# ...          ...       ...            ...               ...              ...
# 161465    1701.0      99.0         1312.0             False            False
# 161466     460.0      66.0           51.0             False            False
# 161467   25900.0     224.0         3881.0             False            False
# 161468    2115.0     182.0         1672.0             False            False
# 161469     300.0      62.0          251.0             False            False
#
#        video_error_or_removed
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 161465                  False
# 161466                  False
# 161467                  False
# 161468                  False
# 161469                  False
#
# [161470 rows x 18 columns]

# %% [markdown]
# COMMENT COUNT

# %%
MMM = [int(DF['comment_count'].mean()), int(DF['comment_count'].mode()[0]), int(DF['comment_count'].median())]
DF['comment_count'].fillna(min(MMM), inplace=True)
DF
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_336\2539717307.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   DF['comment_count'].fillna(min(MMM), inplace=True)
#          index     video_id trending_date  \
# 0            0  2kyS6SvSYSE      17.14.11
# 1            1  1ZAPwfrtAFY      17.14.11
# 2            2  5qpjK5DgCt4      17.14.11
# 3            3  puqaWrEC7tY      17.14.11
# 4            4  d380meD0W0M      17.14.11
# ...        ...          ...           ...
# 161465  161465  sGolxsMSGfQ      18.14.06
# 161466  161466  8HNuRNi8t70      18.14.06
# 161467  161467  GWlKEM3m2EE      18.14.06
# 161468  161468  lbMKLzQ4cNQ      18.14.06
# 161469  161469  POTgw38-m58      18.14.06
#
#                                                     title  \
# 0                      WE WANT TO TALK ABOUT OUR MARRIAGE
# 1       The Trump Presidency: Last Week Tonight with J...
# 2       Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                        Nickelback Lyrics: Real or Fake?
# 4                                I Dare You: GOING BALD!?
# ...                                                   ...
# 161465                       HOW2: How to Solve a Mystery
# 161466                   Eli Lik Lik Episode 13 Partie 01
# 161467  KINGDOM HEARTS III â€“ SQUARE ENIX E3 SHOWCASE...
# 161468                   Trump Advisor Grovels To Trudeau
# 161469  ã€å®Œæ•´ç‰ˆã€‘é‡åˆ°ææ€–æƒ…äººè©²æ€Žéº¼è¾¦ï...
#
#                    channel_title  category_id publish_date      time_frame  \
# 0                   CaseyNeistat           22   13/11/2017  17:00 to 17:59
# 1                LastWeekTonight           24   13/11/2017    7:00 to 7:59
# 2                   Rudy Mancuso           23   12/11/2017  19:00 to 19:59
# 3          Good Mythical Morning           24   13/11/2017  11:00 to 11:59
# 4                       nigahiga           24   12/11/2017  18:00 to 18:59
# ...                          ...          ...          ...             ...
# 161465           Annoying Orange           24   13/06/2018  18:00 to 18:59
# 161466          Elhiwar Ettounsi           24   13/06/2018  19:00 to 19:59
# 161467            Kingdom Hearts           20   11/06/2018  17:00 to 17:59
# 161468           The Young Turks           25   13/06/2018    4:00 to 4:59
# 161469  æˆ‘æ„›å°æ˜Žæ˜Ÿå¤§è·Ÿç­           24   13/06/2018  16:00 to 16:59
#
#        published_day_of_week publish_country  \
# 0                     Monday              US
# 1                     Monday              US
# 2                     Sunday              US
# 3                     Monday              US
# 4                     Sunday              US
# ...                      ...             ...
# 161465             Wednesday          CANADA
# 161466             Wednesday          CANADA
# 161467                Monday          CANADA
# 161468             Wednesday          CANADA
# 161469             Wednesday          CANADA
#
#                                                      tags      views  \
# 0                                                     NaN   748374.0
# 1                                                     NaN  2418783.0
# 2                                                     NaN  3191434.0
# 3                                                     NaN   343168.0
# 4                                                     NaN  2095731.0
# ...                                                   ...        ...
# 161465  annoying orange|"funny"|"fruit"|"talking"|"ani...    80685.0
# 161466  hkayet tounsia|"elhiwar ettounsi"|"denya okhra...   103339.0
# 161467  Kingdom Hearts|"KH3"|"Kingdom Hearts 3"|"Froze...   773347.0
# 161468  180612__TB02SorryExcuse|"News"|"Politics"|"The...   115225.0
# 161469  å³å®—æ†²|"å³å§å„’"|"å°æ˜Žæ˜Ÿå¤§è·Ÿç­"|"Sa...   107392.0
#
#            likes  dislikes  comment_count comments_disabled ratings_disabled  \
# 0        57527.0    2966.0        15954.0             False            False
# 1        97185.0    6146.0        12703.0             False            False
# 2       146033.0    5339.0         8181.0             False            False
# 3        10172.0     666.0         2146.0             False            False
# 4       132235.0    1989.0        17518.0             False            False
# ...          ...       ...            ...               ...              ...
# 161465    1701.0      99.0         1312.0             False            False
# 161466     460.0      66.0           51.0             False            False
# 161467   25900.0     224.0         3881.0             False            False
# 161468    2115.0     182.0         1672.0             False            False
# 161469     300.0      62.0          251.0             False            False
#
#        video_error_or_removed
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 161465                  False
# 161466                  False
# 161467                  False
# 161468                  False
# 161469                  False
#
# [161470 rows x 18 columns]

# %% [markdown]
# COMMENTS DISABLED

# %% [markdown]
# Random by percent

# %%
true_ratio = len(DF[DF['comments_disabled'] == True]) / len(DF)

random_fill = np.random.choice([True, False], size=len(DF), p=[true_ratio, 1 - true_ratio])

DF['comments_disabled'] = DF['comments_disabled'].fillna(pd.Series(random_fill))
# Out:
# C:\Users\minhv\AppData\Local\Temp\ipykernel_336\3893772454.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   YT_Table['comments_disabled'] = YT_Table['comments_disabled'].fillna(pd.Series(random_fill))
